# %% [markdown]
# # COLLECTING IMDBIDS AND TITLES
# ---

# %% [markdown]
# Nhiệm vụ phần này: Từ danh sách các đường dẫn phim của trang web [Just Watch](https://www.justwatch.com/us?age_certifications=G,NC-17,PG,PG-13,R,UNRATED&release_year_from=2023&release_year_until=2024&sort_by=release_year), thực hiện cào thông tin **IMDbID** hoặc **Title** (trong đường dẫn nếu không có ID), **Release year**, **Genre**, **Age rating**, **Runtime** và lưu lại vào file **pre_data_part{x}.csv** với x tương ứng với số thứ tự của thành viên thực hiện cào.

# %% [markdown]
# ## IMPORT

# %%
import time
from selenium import webdriver
from selenium.webdriver import ChromeOptions
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import re
import pandas as pd
import html
import os

# %% [markdown]
# ## 1. CÀO THÔNG TIN IMDbID TRONG TRANG `JUST WATCH`

# %% [markdown]
# - Lấy danh sách các đường dẫn phim đã được thu thập trong phần trước từ file links.txt

# %%
links = []

# Đọc file
with open('../Data/links.txt', 'r') as f:
    links = [line.strip() for line in f]

# %% [markdown]
# - Phân chia phiên làm việc cho các thành viên chịu trách nhiệm phần thu thập dữ liệu. Thông tin của mỗi thành viên sẽ bao gồm:
#
#     - **part**: phần nội dung mà thành viên đó sẽ chịu trách nhiệm
#
#     - **start**: index bắt đầu của đường dẫn từ file links.txt
#
#     - **end**: index kết thúc của đường dẫn từ file links.txt

# %%
# Nhiệm vụ của các thành viên
member_part = {
    "Trinh": {
        "part": 1,
        "start": 0,
        "end": 628
    },

    "Thi": {
        "part": 2,
        "start": 629,
        "end": 1258
    },

    "MinhUyen": {
        "part": 3,
        "start": 1259,
        "end": 1887
    } 
}

# %% [markdown]
# - Mỗi thành viên tiến hành thu thập dữ liệu dựa trên phần nhiệm vụ đã được phân công
#
# - Việc thu thập sẽ được thực hiện độc lập giữa 3 thành viên
#
# - Mỗi thành viên điền tên mình để thực hiện nhiệm vụ được giao

# %%
# Điền tên để tiến hành cào
name = "MinhUyen"
info = member_part[name]

part = info["part"]
start = info["start"]
end = info["end"]

# %% [markdown]
# - Tiến hành thu thập **IMDbID** và **Title**

# %%
# Lấy ID và title của phim dựa vào link cho trước
def collect_imdbID_title(links, start, end):
    # Thiết lập tùy chọn cho trình duyệt Chrome
    option = webdriver.ChromeOptions()

    prefs = {
        "profile.managed_default_content_settings.images": 2,
        "profile.managed_default_content_settings.plugins": 2,
        "profile.managed_default_content_settings.media": 2
    }
    option.add_experimental_option("prefs", prefs)

    # Khởi tạo trình duyệt Chrome với tùy chọn trên
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=option)
    
    # Khởi tạo các danh sách lưu trữ thông tin cần thu thập
    imdbIds_titles = []
    years = []
    genres = []
    age_ratings = []
    runtimes = []

    # Duyệt qua từng URL trong khoảng chỉ định (start -> end)
    for url in links[start:end + 1]:
        print(f"[LOG]: parse imdbid of url {url}")
        driver.get(url)
        time.sleep(4)
        page_source = driver.page_source    # Lấy mã nguồn HTML của trang
        page_source = html.unescape(page_source)    # Giải mã các ký tự HTML đặc biệt

        # Tìm IMDb ID từ mã nguồn trang web
        imdb_id_matches = re.findall(r'"imdbId":"(tt\d+)"', page_source)
        if imdb_id_matches:
            imdb_id = imdb_id_matches[-1]   # Lấy IMDb ID cuối cùng (nếu có nhiều kết quả)
            item = imdb_id
        else:
            # Nếu không tìm thấy IMDb ID, lấy tiêu đề phim từ thẻ meta
            movie_title_meta = driver.find_element(By.XPATH, "//meta[@property='og:title']")
            if movie_title_meta:
                movie_title = movie_title_meta.get_attribute("content").split(" streaming")[0]
                item = movie_title
            else:
                item = "Null"

        # Tìm thể loại phim (Genres) từ mã nguồn trang web
        genre_match = re.search(r'Genres<\/h3><div class="detail-infos__value".*?<span data-v.*?>(.*?)</span>', page_source, re.DOTALL)
        genre = genre_match.group(1) if genre_match else "Null"
        if genre.startswith("<a"): # xử lý trường hợp đặc biệt
            genre = "Mystery & Thriller"

        # Tìm thời lượng phim (Runtime)
        runtime_match = re.search(r'Runtime<\/h3><div class="detail-infos__value"[^>]*>(.*?)<\/div>', page_source)
        runtime = runtime_match.group(1) if runtime_match else "Null"

        # Tìm độ tuổi giới hạn (Age rating)
        age_rating_match = re.search(r'Age rating<\/h3><div class="detail-infos__value"[^>]*>(.*?)<\/div>', page_source)
        age_rating = age_rating_match.group(1) if age_rating_match else "Null"

        # Tìm năm phát hành phim (Release year)
        release_year_match = re.search(r'class="release-year".*?\((\d{4})\)', page_source)
        release_year = release_year_match.group(1) if release_year_match else "Null"

        # In ra kết quả
        print(f"{item} - {release_year} - {age_rating} - {runtime} - {genre}")

        # Cập nhật thông tin đã thu thập được
        imdbIds_titles.append(item)
        years.append(release_year)
        runtimes.append(runtime)
        age_ratings.append(age_rating)
        genres.append(genre)

    # Đóng trình duyệt khi hoàn tất
    driver.quit()

    # Lưu dữ liệu
    df = pd.DataFrame({
        "Id/Title": imdbIds_titles,     # Cột chứa IMDb ID hoặc tiêu đề phim
        "Release year": years,          # Cột chứa năm phát hành
        "Age rating": age_ratings,      # Cột chứa phân loại độ tuổi
        "Runtime": runtimes,            # Cột chứa thời lượng phim
        "Genre": genres                 # Cột chứa thể loại phim
    })

    return df

# %%
# In kết quả
pre_data = collect_imdbID_title(links, start=start, end=end)
pre_data
# Out:
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/in-a-silent-world
# tt5217950 - 2023 - G - 1h 29min - Documentary
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/vikings-battle-of-heirs
# tt21923666 - 2023 - PG - 1h 22min - Mystery & Thriller
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/mistletoe-connection
# tt28225059 - 2023 - G - 1h 30min - Comedy, Romance, Drama
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/disney-intertwined-live
# tt27512578 - 2023 - PG - 1h 8min - Music & Musical, Comedy, Drama, Fantasy
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/thabo-the-rhino-adventure
# tt22755734 - 2023 - PG - 1h 37min - Kids & Family, Action & Adventure, Mystery & Thriller
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/the-modelizer
# tt13482930 - 2023 - R - 1h 36min - Romance, Comedy
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/trapped-in-the-farmhouse
# tt27144976 - 2023 - PG-13 - 1h 30min - Mystery & Thriller
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/psy-summer-swag-2022
# tt27548375 - 2023 - PG - 1h 26min - Documentary, Music & Musical
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/a-royal-christmas-on-ice
# tt19408396 - 2023 - G - 1h 25min - Romance, Comedy, Drama
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/untold-jake-paul-the-problem-child
# tt28089650 - 2023 - R - 1h 10min - Documentary, Sport
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/marvel-studios-assembled-the-making-of-secret-invasion
# Marvel Studios Assembled: The Making of Secret Invasion - 2023 - PG-13 - 48min - Documentary
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/yester-years
# tt28773728 - 2023 - PG-13 - 59min - Mystery & Thriller
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/devanand-dheere-dheere
# tt26698990 - 2023 - PG-13 - 1h 37min - Drama, Romance
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/1992-monarchy-vs-media
# tt22507256 - 2023 - PG-13 - 42min - Documentary
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/made-for-each-other-2023
# tt25391120 - 2023 - G - 1h 24min - Fantasy, Comedy, Romance
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/tiger-3-2023
# tt18411490 - 2023 - PG-13 - 2h 34min - Mystery & Thriller, Action & Adventure
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/wonderwell
# tt6195756 - 2023 - PG-13 - 1h 36min - Drama, Kids & Family, Fantasy, Made in Europe
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/shyamchi-aai
# tt15464490 - 2023 - G - 2h 20min - Drama, Kids & Family
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/chang-can-dunk
# tt13650494 - 2023 - PG - 1h 49min - Kids & Family, Sport, Drama, Comedy
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/cypher-2022
# tt17676714 - 2023 - R - 1h 21min - Documentary, Music & Musical, Drama, Mystery & Thriller
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/stan-lee
# tt25363184 - 2023 - PG - 1h 26min - Documentary
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/gulmohar-2023
# tt18951176 - 2023 - PG-13 - 2h 11min - Kids & Family, Drama
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/secret-society-of-lies
# tt20880984 - 2023 - PG-13 - 1h 28min - Drama
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/reassigned
# tt16916320 - 2023 - R - 1h 37min - Action & Adventure, Mystery & Thriller
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/the-best-man-2023-0
# tt13400336 - 2023 - R - 1h 33min - Action & Adventure, Mystery & Thriller
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/frybread-face-and-me
# tt13365482 - 2023 - R - 1h 22min - Drama, Comedy
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/join-or-die
# tt26081864 - 2023 - PG - 1h 39min - Documentary, Horror
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/ice-cold-murder-coffee-and-jessica-wongso
# tt28840429 - 2023 - PG-13 - 1h 26min - Documentary, Crime
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/our-christmas-mural
# tt29513309 - 2023 - G - 1h 24min - Comedy, Drama, Romance
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/catch-me-if-you-claus
# tt29513295 - 2023 - Null - Null - Null
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/lonesome-soldier-2023
# tt20257492 - 2023 - R - 1h 49min - Drama, War & Military, Mystery & Thriller
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/sen-inandir
# Make Me Believe - 2023 - R - 1h 44min - Romance, Comedy
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/learning-to-love
# tt27682667 - 2023 - G - 1h 30min - Romance, Kids & Family, Comedy, Drama
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/toni-en-famille
# tt23856264 - 2023 - PG-13 - 1h 35min - Comedy, Drama
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/the-abigail-mysteries
# The Abigail Mysteries - 2023 - G - 1h 24min - Mystery & Thriller
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/uproar
# tt20255028 - 2023 - PG-13 - 1h 50min - Drama
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/the-great-turkey-town-miracle
# tt15331620 - 2023 - PG - 1h 23min - Kids & Family, Drama
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/haul-out-the-holly-lit-up
# tt28492358 - 2023 - G - 1h 24min - Comedy, Romance
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/the-last-747
# The Last 747 - 2023 - PG - 45min - Documentary
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/maybe-its-you
# tt4401612 - 2023 - PG-13 - 1h 25min - Comedy
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/swing-into-romance
# tt29381709 - 2023 - G - 1h 25min - Comedy, Romance
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/zombie-town-2023-0
# tt21431644 - 2023 - PG-13 - 1h 33min - Comedy, Action & Adventure, Horror
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/dreamin-wild
# tt10245106 - 2023 - PG - 1h 50min - Music & Musical, Drama
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/monica-2022
# tt6337816 - 2023 - R - 1h 53min - Drama
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/jung_e
# tt22352848 - 2023 - R - 1h 38min - Science-Fiction, Drama
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/my-christmas-hero
# tt27542956 - 2023 - Null - Null - Null
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/one-more-time-2023
# tt21216870 - 2023 - R - 1h 25min - Comedy, Drama, Romance
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/donyale-luna-supermodel
# tt21046314 - 2023 - R - 1h 35min - Documentary
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/the-wedding-contract
# The Wedding Contract - 2023 - G - 1h 24min - Comedy, Romance
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/good-night-2023
# tt26691319 - 2023 - G - 2h 24min - Comedy, Drama, Romance
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/the-taming-of-the-shrewd-2
# The Taming of the Shrewd 2 - 2023 - R - 1h 40min - Comedy, Romance
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/all-souls-2023
# tt14316486 - 2023 - R - 1h 21min - Mystery & Thriller, Action & Adventure, Crime, Drama
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/headshop
# tt6615224 - 2023 - PG-13 - 1h 32min - Comedy
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/guven-bana
# tt21200858 - 2023 - PG-13 - 1h 52min - Comedy, Action & Adventure
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/a-gamers-journey-the-definitive-history-of-shenmue
# tt18935358 - 2023 - PG-13 - 1h 23min - Documentary
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/glisten-and-the-merry-mission
# tt23870264 - 2023 - G - 1h 18min - Action & Adventure, Animation, Kids & Family, Fantasy
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/praise-this
# tt9658388 - 2023 - PG-13 - 1h 41min - Romance, Comedy, Music & Musical
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/ilary-blasi-the-one-and-only
# tt30107921 - 2023 - Null - Null - Null
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/king-of-clones
# King of Clones - 2023 - PG-13 - 1h 25min - Documentary
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/the-magicians-elephant
# tt2560092 - 2023 - PG - 1h 39min - Drama, Kids & Family, Fantasy, Animation, Comedy
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/the-wiggles-the-sound-of-christmas
# The Wiggles: The Sound of Christmas - 2023 - G - 59min - Kids & Family
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/mothers-day-2023
# tt19724192 - 2023 - R - 1h 34min - Mystery & Thriller, Action & Adventure, Drama
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/assassin-club
# tt7720142 - 2023 - Null - Null - Null
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/carlos-2023
# tt20417104 - 2023 - R - 1h 27min - Documentary, Music & Musical
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/gen-hoshino-concert-recollections-2015-2023
# Gen Hoshino Concert Recollections 2015-2023 - 2023 - R - 1h 13min - Music & Musical
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/the-devil-on-trial
# tt28810493 - 2023 - R - 1h 21min - Documentary, Crime, Horror
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/a-place-in-the-field
# A Place in the Field - 2023 - R - 1h 22min - Drama
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/trading-places-2023
# Trading Places - 2023 - R - 1h 36min - Comedy
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/sick-girl-2006
# tt3701150 - 2023 - R - 1h 39min - Comedy, Drama, Horror
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/el-club-de-los-lectores-criminales
# tt18260564 - 2023 - R - 1h 29min - Mystery & Thriller, Horror
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/coffee-wars
# tt11426538 - 2023 - R - 1h 44min - Comedy
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/fashion-reimagined
# tt18292986 - 2023 - R - 1h 40min - Documentary
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/total-trust
# tt27148236 - 2023 - R - 1h 37min - Documentary
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/being-mary-tyler-moore
# tt26084136 - 2023 - PG - 1h 59min - Documentary
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/the-price-we-pay-2022
# tt15441472 - 2023 - R - 1h 26min - Horror, Mystery & Thriller, Action & Adventure, Crime
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/far-haven
# tt23647954 - 2023 - PG - 1h 41min - Western, Drama, Action & Adventure
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/mafia-mamma
# Mafia Mamma - 2023 - R - 1h 41min - Crime, Action & Adventure, Comedy
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/christmas-time
# tt10338176 - 2023 - G - 1h 35min - Comedy, Kids & Family, Fantasy
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/mending-the-line
# tt9201772 - 2023 - R - 1h 57min - Drama, War & Military
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/our-son
# tt20833316 - 2023 - R - 1h 44min - Drama, Crime
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/filip
# tt15460742 - 2023 - R - 1h 59min - War & Military, Drama, History
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/poor-things
# tt14230458 - 2023 - R - 2h 22min - Science-Fiction, Romance, Comedy, Drama
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/the-starling-girl
# tt21156390 - 2023 - R - 1h 56min - Drama
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/santa-maybe
# tt29931745 - 2023 - G - 1h 24min - Comedy, Romance, Drama
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/dear-david-2023
# tt9288740 - 2023 - R - 1h 34min - Horror, Mystery & Thriller
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/justice-league-x-rwby-super-heroes-and-huntsmen-part-one
# tt24548912 - 2023 - PG - 1h 23min - Animation, Action & Adventure, Fantasy
# [LOG]: parse imdbid of url https://www.justwatch.com/us/movie/my-crime
# tt20330434 - 2023 - R - 1h 43min - Mystery & Thriller, Drama, Crime, Comedy
#       Id/Title Release year Age rating   Runtime  \
# 0    tt5217950         2023          G  1h 29min
# 1   tt21923666         2023         PG  1h 22min
# 2   tt28225059         2023          G  1h 30min
# 3   tt27512578         2023         PG   1h 8min
# 4   tt22755734         2023         PG  1h 37min
# ..         ...          ...        ...       ...
# 82  tt21156390         2023          R  1h 56min
# 83  tt29931745         2023          G  1h 24min
# 84   tt9288740         2023          R  1h 34min
# 85  tt24548912         2023         PG  1h 23min
# 86  tt20330434         2023          R  1h 43min
#
#                                                 Genre
# 0                                         Documentary
# 1                                  Mystery & Thriller
# 2                              Comedy, Romance, Drama
# 3             Music & Musical, Comedy, Drama, Fantasy
# 4   Kids & Family, Action & Adventure, Mystery & T...
# ..                                                ...
# 82                                              Drama
# 83                             Comedy, Romance, Drama
# 84                         Horror, Mystery & Thriller
# 85             Animation, Action & Adventure, Fantasy
# 86           Mystery & Thriller, Drama, Crime, Comedy
#
# [87 rows x 5 columns]

# %% [markdown]
# ## 2. LƯU FILE

# %% [markdown]
# Lưu thông tin vừa thu thập được vào file csv

# %%
file_name = f"../Data/pre_data_part{part}.csv"

if os.path.isfile(file_name):
    pre_data.to_csv(file_name, mode='a', header=False, index=False)
else:
    pre_data.to_csv(file_name, mode='w', header=True, index=False)
